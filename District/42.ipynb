# %%
import pandas as pd

# Replace 'file_path' with the actual path to your file
file_path = "42_District_wise_crimes_committed_against_women_2013.csv"

# Read the CSV file into a DataFrame
df= pd.read_csv(file_path)

# %%
import pandas as pd

# Replace 'file_path' with the actual path to your file
file_path = "42_District_wise_crimes_committed_against_women_2014.csv"

# Read the CSV file into a DataFrame
df1 = pd.read_csv(file_path)

# %%
df
# Out:
#            STATE/UT     DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0    Andhra Pradesh     ADILABAD  2013    61                        47
# 1    Andhra Pradesh    ANANTAPUR  2013    28                        84
# 2    Andhra Pradesh     CHITTOOR  2013    31                        27
# 3    Andhra Pradesh     CUDDAPAH  2013    19                        50
# 4    Andhra Pradesh    CYBERABAD  2013   138                       129
# ..              ...          ...   ...   ...                       ...
# 818     Lakshadweep  LAKSHADWEEP  2013     2                         0
# 819     Lakshadweep     ZZ TOTAL  2013     2                         0
# 820      Puducherry     KARAIKAL  2013     6                         2
# 821      Puducherry   PUDUCHERRY  2013    11                        23
# 822      Puducherry     ZZ TOTAL  2013    17                        25
#
#      Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['States/UTs', 'District', 'Year', 'Rape', 'Custodial Rape',
#        'Custodial_Gang Rape', 'Custodial_Other Rape',
#        'Rape other than Custodial', 'Rape_Gang Rape', 'Rape_Others',
#        'Attempt to commit Rape', 'Kidnapping & Abduction_Total',
#        'Kidnaping & Abduction', 'Kidnaping & Abduction in order to Murder',
#        'Kidnapping for Ransom',
#        'Kidnapping & Abduction of Women to compel her for marriage',
#        'Kidnaping & Abduction_Others', 'Dowry Deaths',
#        'Assault on Women with intent to outrage her Modesty_Total',
#        'Sexual Harassment', 'Assault on women with intent to Disrobe',
#        'Voyeurism', 'Stalking', 'Others',
#        'Insult to the Modesty of Women_Total', 'At Office premises',
#        'In places related to work', 'In Public Transport system',
#        'In other Places', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls from Foreign Country', 'Murder',
# ...

# %%
import pandas as pd

# Columns for df
columns_df = ['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
              'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
              'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
              'Importation of Girls']

# Columns for df1
columns_df1 = ['States/UTs', 'District', 'Year', 'Rape', 'Custodial Rape',
               'Custodial_Gang Rape', 'Custodial_Other Rape',
               'Rape other than Custodial', 'Rape_Gang Rape', 'Rape_Others',
               'Attempt to commit Rape', 'Kidnapping & Abduction_Total',
               'Kidnaping & Abduction', 'Kidnaping & Abduction in order to Murder',
               'Kidnapping for Ransom',
               'Kidnapping & Abduction of Women to compel her for marriage',
               'Kidnaping & Abduction_Others', 'Dowry Deaths',
               'Assault on Women with intent to outrage her Modesty_Total',
               'Sexual Harassment', 'Assault on women with intent to Disrobe',
               'Voyeurism', 'Stalking', 'Others',
               'Insult to the Modesty of Women_Total', 'At Office premises',
               'In places related to work', 'In Public Transport system',
               'In other Places', 'Cruelty by Husband or his Relatives',
               'Importation of Girls from Foreign Country', 'Murder',
               'Attempt to commit Murder', 'Culpable Homicide not amounting to Murder',
               'Attempt to commit Culpable Homicide', 'Grievous Hurt', 'Hurt',
               'Acid attack', 'Attempt to Acid Attack',
               'Deaths caused with intent to cause miscarriage',
               'Causing miscarriage without consent of women', 'Dacoity_Total',
               'Dacoity with Murder', 'Other Dacoity', 'Robbery', 'Arson',
               'HumanTrafficking', 'Abetment of Suicides of Women',
               'UnNatural Offences', 'Other IPC Crimes against Women',
               'Dowry Prohibition Act, 1961',
               'Indecent Representation of Women (P) Act, 1986',
               'Commission of Sati Prevention Act, 1987',
               'Protection of Women from Domestic Violence Act, 2005',
               'Immoral Traffic Prevention Act', 'ITP Under Section 5',
               'ITP Under Section 6', 'ITP Under Section 7', 'ITP Under Section 8',
               'ITP Under Other Sections', 'Other SLL Crimes against Women',
               'Total Crimes against Women']

# Read the data into DataFrames
df = pd.read_csv("42_District_wise_crimes_committed_against_women_2013.csv")
df1 = pd.read_csv("42_District_wise_crimes_committed_against_women_2014.csv")

# Set 'STATE/UT' and 'DISTRICT' as index for both DataFrames
df.set_index(['STATE/UT', 'DISTRICT'], inplace=True)
df1.set_index(['States/UTs', 'District'], inplace=True)

# Concatenate the DataFrames along the index axis
combined_df = pd.concat([df, df1], axis=0, sort=False)

# Reset index to bring 'STATE/UT' and 'DISTRICT' back to columns
combined_df.reset_index(inplace=True)

# Display combined DataFrame
print(combined_df.head())
# Out:
#          STATE/UT   DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  Andhra Pradesh   ADILABAD  2013    61                      47.0
# 1  Andhra Pradesh  ANANTAPUR  2013    28                      84.0
# 2  Andhra Pradesh   CHITTOOR  2013    31                      27.0
# 3  Andhra Pradesh   CUDDAPAH  2013    19                      50.0
# 4  Andhra Pradesh  CYBERABAD  2013   138                     129.0
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            12                                              197.0
# 1            23                                              337.0
# 2            13                                              119.0
# 3             9                                              318.0
# 4            43                                              350.0
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                       138.0                                  464
# ...

# %%
combined_df
# Out:
#             STATE/UT     DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     Andhra Pradesh     ADILABAD  2013    61                      47.0
# 1     Andhra Pradesh    ANANTAPUR  2013    28                      84.0
# 2     Andhra Pradesh     CHITTOOR  2013    31                      27.0
# 3     Andhra Pradesh     CUDDAPAH  2013    19                      50.0
# 4     Andhra Pradesh    CYBERABAD  2013   138                     129.0
# ...              ...          ...   ...   ...                       ...
# 1655     Lakshadweep  Lakshadweep  2014     1                       NaN
# 1656     Lakshadweep        Total  2014     1                       NaN
# 1657      Puducherry     Karaikal  2014     3                       NaN
# 1658      Puducherry   Puducherry  2014     7                       NaN
# 1659      Puducherry        Total  2014    10                       NaN
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
combined_df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls', 'Custodial Rape', 'Custodial_Gang Rape',
#        'Custodial_Other Rape', 'Rape other than Custodial', 'Rape_Gang Rape',
#        'Rape_Others', 'Attempt to commit Rape', 'Kidnapping & Abduction_Total',
#        'Kidnaping & Abduction', 'Kidnaping & Abduction in order to Murder',
#        'Kidnapping for Ransom',
#        'Kidnapping & Abduction of Women to compel her for marriage',
#        'Kidnaping & Abduction_Others',
#        'Assault on Women with intent to outrage her Modesty_Total',
#        'Sexual Harassment', 'Assault on women with intent to Disrobe',
#        'Voyeurism', 'Stalking', 'Others',
#        'Insult to the Modesty of Women_Total', 'At Office premises',
# ...

# %%
import matplotlib.pyplot as plt

# Group by Year and sum the crimes
yearly_data = combined_df.groupby('Year').sum()

# Plot the trends over the years
plt.figure(figsize=(10, 5))
plt.plot(yearly_data.index, yearly_data['Total Crimes against Women'])
plt.xlabel('Year')
plt.ylabel('Total Crimes against Women')
plt.title('Trend of Total Crimes against Women Over the Years')
plt.show()
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_7176\3165776139.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yearly_data = combined_df.groupby('Year').sum()

# %%
# Group by State and sum the crimes
state_data = combined_df.groupby('STATE/UT').sum()

# Plot the comparison of states
state_data['Total Crimes against Women'].sort_values().plot(kind='barh', figsize=(10, 15))
plt.xlabel('Total Crimes against Women')
plt.title('Total Crimes against Women by State/UT')
plt.show()
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_7176\2056509388.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_data = combined_df.groupby('STATE/UT').sum()

# %%
import pandas as pd

# Assuming combined_df is your dataframe
# Group by 'DISTRICT' and sum up the crimes
district_data = combined_df.groupby('DISTRICT').sum()

# Display the first few rows to understand the structure
print(district_data.head())
# Out:
#                    Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# DISTRICT
# 24 PARGANAS NORTH  2013   115                     258.0            35
# 24 PARGANAS SOUTH  2013   189                     397.0            49
# ADILABAD           2013    61                      47.0            12
# AGAR               2013    24                       8.0             1
# AGRA               2013    78                     335.0            98
#
#                    Assault on women with intent to outrage her modesty  \
# DISTRICT
# 24 PARGANAS NORTH                                              307.0
# 24 PARGANAS SOUTH                                              212.0
# ADILABAD                                                       197.0
# AGAR                                                            41.0
# AGRA                                                           239.0
#
#                    Insult to modesty of Women  \
# DISTRICT
# ...

# %%
# Group by State and sum the crimes
state_data = combined_df.groupby('STATE/UT').sum()

# Plot the comparison of states
state_data['Total Crimes against Women'].sort_values().plot(kind='barh', figsize=(10, 15))
plt.xlabel('Total Crimes against Women')
plt.title('Total Crimes against Women by State/UT')
plt.show()
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_7176\4273456022.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_data = combined_df.groupby('STATE/UT').sum()

# %%
import pandas as pd

# Assuming combined_df is your dataframe
# Load your dataframe here
# combined_df = pd.read_csv('your_dataset.csv')

# Create new combined columns by summing up the similar columns
combined_df['Total_Kidnapping_Abduction'] = (
    combined_df['Kidnapping and Abduction'] +
    combined_df['Kidnaping & Abduction'] +
    combined_df['Kidnaping & Abduction in order to Murder'] +
    combined_df['Kidnapping for Ransom'] +
    combined_df['Kidnapping & Abduction of Women to compel her for marriage'] +
    combined_df['Kidnaping & Abduction_Others']
)

combined_df['Total_Rape'] = (
    combined_df['Rape'] +
    combined_df['Custodial Rape'] +
    combined_df['Custodial_Gang Rape'] +
    combined_df['Custodial_Other Rape'] +
    combined_df['Rape other than Custodial'] +
    combined_df['Rape_Gang Rape'] +
    combined_df['Rape_Others'] +
    combined_df['Attempt to commit Rape']
)

combined_df['Total_Assault_on_Women'] = (
    combined_df['Assault on women with intent to outrage her modesty'] +
    combined_df['Assault on Women with intent to outrage her Modesty_Total'] +
    combined_df['Assault on women with intent to Disrobe']
)

combined_df['Total_Insult_to_Modesty'] = (
    combined_df['Insult to modesty of Women'] +
    combined_df['Insult to the Modesty of Women_Total']
)

combined_df['Total_Acid_Attack'] = (
    combined_df['Acid attack'] +
    combined_df['Attempt to Acid Attack']
)

combined_df['Total_Human_Trafficking'] = (
    combined_df['HumanTrafficking'] +
    combined_df['Importation of Girls'] +
    combined_df['Importation of Girls from Foreign Country'] +
    combined_df['Immoral Traffic Prevention Act'] +
    combined_df['ITP Under Section 5'] +
    combined_df['ITP Under Section 6'] +
    combined_df['ITP Under Section 7'] +
    combined_df['ITP Under Section 8'] +
    combined_df['ITP Under Other Sections']
)

combined_df['Total_Custodial_Crimes'] = (
    combined_df['Custodial Rape'] +
    combined_df['Custodial_Gang Rape'] +
    combined_df['Custodial_Other Rape']
)

combined_df['Total_Dowry_Related_Crimes'] = (
    combined_df['Dowry Deaths'] +
    combined_df['Dowry Prohibition Act, 1961']
)

# Drop the original columns if needed
combined_df.drop(columns=[
    'Kidnapping and Abduction', 'Kidnaping & Abduction', 'Kidnaping & Abduction in order to Murder',
    'Kidnapping for Ransom', 'Kidnapping & Abduction of Women to compel her for marriage',
    'Kidnaping & Abduction_Others', 'Rape', 'Custodial Rape', 'Custodial_Gang Rape',
    'Custodial_Other Rape', 'Rape other than Custodial', 'Rape_Gang Rape', 'Rape_Others',
    'Attempt to commit Rape', 'Assault on women with intent to outrage her modesty',
    'Assault on Women with intent to outrage her Modesty_Total', 'Assault on women with intent to Disrobe',
    'Insult to modesty of Women', 'Insult to the Modesty of Women_Total', 'Acid attack', 'Attempt to Acid Attack',
    'HumanTrafficking', 'Importation of Girls', 'Importation of Girls from Foreign Country',
    'Immoral Traffic Prevention Act', 'ITP Under Section 5', 'ITP Under Section 6', 'ITP Under Section 7',
    'ITP Under Section 8', 'ITP Under Other Sections', 'Custodial Rape', 'Custodial_Gang Rape',
    'Custodial_Other Rape', 'Dowry Deaths', 'Dowry Prohibition Act, 1961'
], inplace=True)

# Save the combined dataframe to a new CSV file if needed
# combined_df.to_csv('combined_dataset.csv', index=False)

combined_df.head()
# Out:
#          STATE/UT   DISTRICT  Year  Cruelty by Husband or his Relatives  \
# 0  Andhra Pradesh   ADILABAD  2013                                  464
# 1  Andhra Pradesh  ANANTAPUR  2013                                  161
# 2  Andhra Pradesh   CHITTOOR  2013                                  435
# 3  Andhra Pradesh   CUDDAPAH  2013                                  207
# 4  Andhra Pradesh  CYBERABAD  2013                                 1526
#
#    Kidnapping & Abduction_Total  Sexual Harassment  Voyeurism  Stalking  \
# 0                           NaN                NaN        NaN       NaN
# 1                           NaN                NaN        NaN       NaN
# 2                           NaN                NaN        NaN       NaN
# 3                           NaN                NaN        NaN       NaN
# 4                           NaN                NaN        NaN       NaN
#
#    Others  At Office premises  ...  Other SLL Crimes against Women  \
# ...

# %%
import pandas as pd

# Assuming combined_df is your dataframe
# Group by 'DISTRICT' and sum up the crimes
district_data = combined_df.groupby('DISTRICT').sum()

# Display the first few rows to understand the structure
print(district_data.head())
# Out:
#                    Year  Cruelty by Husband or his Relatives  \
# DISTRICT
# 24 PARGANAS NORTH  2013                                 1716
# 24 PARGANAS SOUTH  2013                                 1978
# ADILABAD           2013                                  464
# AGAR               2013                                   30
# AGRA               2013                                  399
#
#                    Kidnapping & Abduction_Total  Sexual Harassment  Voyeurism  \
# DISTRICT
# 24 PARGANAS NORTH                           0.0                0.0        0.0
# 24 PARGANAS SOUTH                           0.0                0.0        0.0
# ADILABAD                                    0.0                0.0        0.0
# AGAR                                        0.0                0.0        0.0
# AGRA                                        0.0                0.0        0.0
#
#                    Stalking  Others  At Office premises  \
# DISTRICT
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataframe here
# combined_df = pd.read_csv('your_dataset.csv')

# Group by STATE/UT and sum the crimes
state_crime_totals = combined_df.groupby('STATE/UT').sum()

# Get the top 5 states for each crime
top_states_kidnapping_abduction = state_crime_totals['Total_Kidnapping_Abduction'].sort_values(ascending=False).head(5)
top_states_rape = state_crime_totals['Total_Rape'].sort_values(ascending=False).head(5)
top_states_assault = state_crime_totals['Total_Assault_on_Women'].sort_values(ascending=False).head(5)
top_states_insult = state_crime_totals['Total_Insult_to_Modesty'].sort_values(ascending=False).head(5)
top_states_acid_attack = state_crime_totals['Total_Acid_Attack'].sort_values(ascending=False).head(5)
top_states_human_trafficking = state_crime_totals['Total_Human_Trafficking'].sort_values(ascending=False).head(5)
top_states_custodial_crimes = state_crime_totals['Total_Custodial_Crimes'].sort_values(ascending=False).head(5)
top_states_dowry_related = state_crime_totals['Total_Dowry_Related_Crimes'].sort_values(ascending=False).head(5)

# Function to plot the top 5 states for a specific crime
def plot_top_states(data, title, ylabel):
    data.plot(kind='bar', figsize=(10, 6), color='skyblue')
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel('STATE/UT')
    plt.xticks(rotation=45)
    plt.show()

# Plotting the top 5 states for each crime
plot_top_states(top_states_kidnapping_abduction, 'Top 5 States for Kidnapping & Abduction', 'Number of Cases')
plot_top_states(top_states_rape, 'Top 5 States for Rape', 'Number of Cases')
plot_top_states(top_states_assault, 'Top 5 States for Assault on Women', 'Number of Cases')
plot_top_states(top_states_insult, 'Top 5 States for Insult to Modesty', 'Number of Cases')
plot_top_states(top_states_acid_attack, 'Top 5 States for Acid Attack', 'Number of Cases')
plot_top_states(top_states_human_trafficking, 'Top 5 States for Human Trafficking', 'Number of Cases')
plot_top_states(top_states_custodial_crimes, 'Top 5 States for Custodial Crimes', 'Number of Cases')
plot_top_states(top_states_dowry_related, 'Top 5 States for Dowry Related Crimes', 'Number of Cases')

# Group by DISTRICT and sum the crimes
district_crime_totals = combined_df.groupby('DISTRICT').sum()

# Get the top 5 districts for each crime
top_districts_kidnapping_abduction = district_crime_totals['Total_Kidnapping_Abduction'].sort_values(ascending=False).head(5)
top_districts_rape = district_crime_totals['Total_Rape'].sort_values(ascending=False).head(5)
top_districts_assault = district_crime_totals['Total_Assault_on_Women'].sort_values(ascending=False).head(5)
top_districts_insult = district_crime_totals['Total_Insult_to_Modesty'].sort_values(ascending=False).head(5)
top_districts_acid_attack = district_crime_totals['Total_Acid_Attack'].sort_values(ascending=False).head(5)
top_districts_human_trafficking = district_crime_totals['Total_Human_Trafficking'].sort_values(ascending=False).head(5)
top_districts_custodial_crimes = district_crime_totals['Total_Custodial_Crimes'].sort_values(ascending=False).head(5)
top_districts_dowry_related = district_crime_totals['Total_Dowry_Related_Crimes'].sort_values(ascending=False).head(5)

# Function to plot the top 5 districts for a specific crime
def plot_top_districts(data, title, ylabel):
    data.plot(kind='bar', figsize=(10, 6), color='coral')
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel('DISTRICT')
    plt.xticks(rotation=45)
    plt.show()

# Plotting the top 5 districts for each crime
plot_top_districts(top_districts_kidnapping_abduction, 'Top 5 Districts for Kidnapping & Abduction', 'Number of Cases')
plot_top_districts(top_districts_rape, 'Top 5 Districts for Rape', 'Number of Cases')
plot_top_districts(top_districts_assault, 'Top 5 Districts for Assault on Women', 'Number of Cases')
plot_top_districts(top_districts_insult, 'Top 5 Districts for Insult to Modesty', 'Number of Cases')
plot_top_districts(top_districts_acid_attack, 'Top 5 Districts for Acid Attack', 'Number of Cases')
plot_top_districts(top_districts_human_trafficking, 'Top 5 Districts for Human Trafficking', 'Number of Cases')
plot_top_districts(top_districts_custodial_crimes, 'Top 5 Districts for Custodial Crimes', 'Number of Cases')
plot_top_districts(top_districts_dowry_related, 'Top 5 Districts for Dowry Related Crimes', 'Number of Cases')
# Out:
# C:\Users\sohan\AppData\Local\Temp\ipykernel_7176\2210261410.py:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   state_crime_totals = combined_df.groupby('STATE/UT').sum()
# C:\Users\sohan\AppData\Local\Temp\ipykernel_7176\2210261410.py:40: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   district_crime_totals = combined_df.groupby('DISTRICT').sum()

# %%
# Read the data into DataFrames
df = pd.read_csv("01_District_wise_crimes_committed_IPC_2001_2012.csv")
df1 = pd.read_csv("01_District_wise_crimes_committed_IPC_2013.csv")
df2 = pd.read_csv("01_District_wise_crimes_committed_IPC_2014.csv")

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['States/UTs', 'District', 'Year', 'Murder', 'Attempt to commit Murder',
#        'Culpable Homicide not amounting to Murder',
#        'Attempt to commit Culpable Homicide', 'Rape', 'Custodial Rape',
#        'Custodial_Gang Rape', 'Custodial_Other Rape',
#        'Rape other than Custodial', 'Rape_Gang Rape', 'Rape_Others',
#        'Attempt to commit Rape', 'Kidnapping & Abduction_Total',
#        'Kidnapping & Abduction', 'Kidnapping & Abduction in order to Murder',
#        'Kidnapping for Ransom',
#        'Kidnapping & Abduction of Women to compel her for marriage',
#        'Other Kidnapping', 'Dacoity', 'Dacoity with Murder', 'Other Dacoity',
#        'Making Preparation and Assembly for committing Dacoity', 'Robbery',
#        'Criminal Trespass/Burglary', 'Criminal Trespass or Burglary',
#        'House Trespass & House Breaking', 'Theft', 'Auto Theft',
#        'Other Thefts', 'Unlawful Assembly', 'Riots', 'Riots_Communal',
# ...
